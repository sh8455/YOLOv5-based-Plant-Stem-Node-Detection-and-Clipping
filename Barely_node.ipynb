# %%
# 데이터셋을 사용하기 위한 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# yolov5를 사용하기 위해 import, 모델 사용에 필요한 requirements.txt 설치
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -qr requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 14112, done.
# remote: Counting objects: 100% (339/339), done.
# remote: Compressing objects: 100% (189/189), done.
# remote: Total 14112 (delta 232), reused 226 (delta 150), pack-reused 13773
# Receiving objects: 100% (14112/14112), 13.68 MiB | 11.68 MiB/s, done.
# Resolving deltas: 100% (9659/9659), done.
# /content/yolov5
#      |████████████████████████████████| 182 kB 35.1 MB/s
#      |████████████████████████████████| 1.6 MB 50.4 MB/s

# %%
# 이 코드를 실행하지 않으면 train에서 에러 발생. 꼭 실행시켜야 함
# !pip install -U PyYAML
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# 모델 학습 진행 (img size 640, batch size 16, epochs 250으로 조건 설정)
# yolov5m 모델 사용함
# !python train.py --img 640 --batch 16 --epochs 250 --data /content/drive/MyDrive/custom_dataset/data.yaml --cfg ./models/yolov5m.yaml --weights yolov5m.pt --name [barely_node_model_1]
# Out:
# train: weights=yolov5s.pt, cfg=./models/yolov5s.yaml, data=/content/drive/MyDrive/custom_dataset/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=5, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=[barely_node_model_1], exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-267-gbe348cc Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# 학습된 모델 best.pt를 내 구글 드라이브에 저장하기 위한 코드
# %cp /content/yolov5/runs/train/[barely_node_model_1]/weights/best.pt /content/drive/My\ Drive

# %%
# 학습된 데이터를 테스트해보기 위한 코드, 테스트 데이터로는 custom_dataset의 test에서 images만 사용(labels은 사용하지 않음)
# !python detect.py --weights /content/yolov5/runs/train/[barely_node_model_1]/weights/best.pt --img 640 --conf 0.4 --source /content/drive/MyDrive/custom_dataset/test/images
# Out:
# detect: weights=['/content/yolov5/runs/train/[barely_node_model_1]/weights/best.pt'], source=/content/drive/MyDrive/custom_dataset/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-186-g7f097dd Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# YOLOv5m summary: 212 layers, 20856975 parameters, 0 gradients, 47.9 GFLOPs
# image 1/376 /content/drive/MyDrive/custom_dataset/test/images/barely_2604.png: 480x640 1 node, 23.3ms
# image 2/376 /content/drive/MyDrive/custom_dataset/test/images/barely_2605.png: 480x640 1 node, 23.1ms
# ...

# %%
# 학습된 모델을 동영상을 사용하여 테스트해보기 위한 코드
# !python detect.py --weights /content/yolov5/runs/train/[barely_node_model_1]/weights/best.pt --img 640 --conf 0.4 --source /content/drive/MyDrive/custom_dataset/test/test_media.mp4
# Out:
# python3: can't open file 'detect.py': [Errno 2] No such file or directory
